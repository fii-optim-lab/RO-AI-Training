# %% [markdown]
# <a href="https://colab.research.google.com/github/fii-optim-lab/RO-AI-Training/blob/master/session01-Python-for-AI/02-NumpyExercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/fii-optim-lab/RO-AI-Training/blob/master/session01-Python-for-AI/02-NumpyExercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NumPy exercises
#
# Check the exercises from https://www.machinelearningplus.com/python/101-numpy-exercises-python/ and solve each of them in a separate cell.

# %% [markdown]
# 1. Import `numpy` as `np` and print it's version.
# <details><summary>Answer</summary>
# import numpy as np
# <br>
# print(np.__version__)
# </details>

# %%
import numpy as np
np.__version__
